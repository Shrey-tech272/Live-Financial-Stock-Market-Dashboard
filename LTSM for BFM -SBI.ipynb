# %%
pip install yfinance pandas numpy scikit-learn matplotlib tensorflow
# Out:
# Requirement already satisfied: yfinance in c:\users\aditi\anaconda3\lib\site-packages (0.2.65)
# Requirement already satisfied: pandas in c:\users\aditi\anaconda3\lib\site-packages (2.3.1)
# Requirement already satisfied: numpy in c:\users\aditi\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: scikit-learn in c:\users\aditi\anaconda3\lib\site-packages (1.7.1)
# Requirement already satisfied: matplotlib in c:\users\aditi\anaconda3\lib\site-packages (3.9.2)
# Requirement already satisfied: tensorflow in c:\users\aditi\anaconda3\lib\site-packages (2.20.0)
# Requirement already satisfied: requests>=2.31 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (2.32.3)
# Requirement already satisfied: multitasking>=0.0.7 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (3.10.0)
# Requirement already satisfied: pytz>=2022.5 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (2.4.2)
# Requirement already satisfied: peewee>=3.16.2 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (3.18.2)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (4.12.3)
# Requirement already satisfied: curl_cffi>=0.7 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (0.13.0)
# Requirement already satisfied: protobuf>=3.19.0 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in c:\users\aditi\anaconda3\lib\site-packages (from yfinance) (15.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\aditi\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aditi\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\aditi\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aditi\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aditi\anaconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aditi\anaconda3\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (2.3.1)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google_pasta>=0.1.1 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: setuptools in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (80.9.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (4.14.1)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (1.14.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (1.74.0)
# Requirement already satisfied: tensorboard~=2.20.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (3.11.3)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (3.11.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in c:\users\aditi\anaconda3\lib\site-packages (from tensorflow) (0.5.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aditi\anaconda3\lib\site-packages (from requests>=2.31->yfinance) (2025.8.3)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aditi\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.4.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\aditi\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\aditi\anaconda3\lib\site-packages (from tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aditi\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aditi\anaconda3\lib\site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.5)
# Requirement already satisfied: cffi>=1.12.0 in c:\users\aditi\anaconda3\lib\site-packages (from curl_cffi>=0.7->yfinance) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\aditi\anaconda3\lib\site-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (2.21)
# Requirement already satisfied: rich in c:\users\aditi\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (13.7.1)
# Requirement already satisfied: namex in c:\users\aditi\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in c:\users\aditi\anaconda3\lib\site-packages (from keras>=3.10.0->tensorflow) (0.17.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\aditi\anaconda3\lib\site-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (2.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\aditi\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\aditi\anaconda3\lib\site-packages (from rich->keras>=3.10.0->tensorflow) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\aditi\anaconda3\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import datetime
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.metrics import mean_absolute_percentage_error, mean_squared_error

# %%
stock_symbol = 'SBIN.NS'   # NSE India ticker
df = yf.download(stock_symbol, start='2015-01-01', end='2025-09-29')
# Out:
# C:\Users\Aditi\AppData\Local\Temp\ipykernel_10192\431599126.py:2: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(stock_symbol, start='2015-01-01', end='2025-09-29')
# [*********************100%***********************]  1 of 1 completed

# %%
# Save data to CSV
df.to_csv('SBIN.csv')

# %%
# 2. Data Preprocessing
# Use the 'Close' column as target variable for LSTM model
data = df['Close'].values.reshape(-1, 1)

# %%
# Normalize the data using MinMaxScaler (scale values between 0 and 1)
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_data = scaler.fit_transform(data)

# %%
# Define the length of the training data (80% of total data)
training_data_len = int(np.ceil(len(scaled_data) * 0.8))

# %%
# Split the data into training and testing sets
train_data = scaled_data[0:training_data_len, :]
test_data = scaled_data[training_data_len - 70:, :]

# %%
# Create x_train and y_train datasets
x_train = []
y_train = []

# %%
for i in range(70, len(train_data)):
    x_train.append(train_data[i-70:i, 0])
    y_train.append(train_data[i, 0])

# %%
# Convert x_train and y_train to numpy arrays
x_train, y_train = np.array(x_train), np.array(y_train)

# %%
# Reshape the data to 3D for LSTM (samples, time steps, features)
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))

# %%
# 3. Build the LSTM Model
model = Sequential()
model.add(LSTM(units=45, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(units=45, return_sequences=False))
model.add(Dense(units=25))
model.add(Dense(units=1))
# Out:
# C:\Users\Aditi\anaconda3\Lib\site-packages\keras\src\layers\rnn\rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
# Train the model
model.fit(x_train, y_train, batch_size=16, epochs=200)
# Out:
# Epoch 1/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 8.3628e-05
# Epoch 2/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 7.8837e-05
# Epoch 3/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 9.2197e-05
# Epoch 4/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 7.8567e-05
# Epoch 5/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - loss: 7.8625e-05
# Epoch 6/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 8.5112e-05
# Epoch 7/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 78ms/step - loss: 8.7959e-05
# Epoch 8/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 74ms/step - loss: 7.8189e-05
# Epoch 9/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 8.5091e-05
# Epoch 10/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 8.1594e-05
# Epoch 11/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 73ms/step - loss: 8.9620e-05
# Epoch 12/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 8.4469e-05
# Epoch 13/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 7.9337e-05
# Epoch 14/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 63ms/step - loss: 8.2608e-05
# Epoch 15/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 8.0977e-05
# Epoch 16/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 8.3657e-05
# Epoch 17/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 7.9819e-05
# Epoch 18/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 8.0106e-05
# Epoch 19/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 7.6295e-05
# Epoch 20/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 14s 108ms/step - loss: 8.1400e-05
# Epoch 21/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 24s 186ms/step - loss: 7.3387e-05
# Epoch 22/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 18s 134ms/step - loss: 7.9783e-05
# Epoch 23/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 104ms/step - loss: 8.2574e-05
# Epoch 24/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 8.6674e-05
# Epoch 25/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 92ms/step - loss: 7.7371e-05
# Epoch 26/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - loss: 8.2484e-05
# Epoch 27/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 111ms/step - loss: 8.2764e-05
# Epoch 28/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - loss: 8.4563e-05
# Epoch 29/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 117ms/step - loss: 8.4705e-05
# Epoch 30/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 7.9396e-05
# Epoch 31/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 7.8803e-05
# Epoch 32/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 7.9778e-05
# Epoch 33/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 66ms/step - loss: 8.5408e-05
# Epoch 34/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 75ms/step - loss: 8.6769e-05
# Epoch 35/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 63ms/step - loss: 8.1035e-05
# Epoch 36/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 7.5396e-05
# Epoch 37/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 8.7887e-05
# Epoch 38/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - loss: 7.7451e-05
# Epoch 39/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 9.1790e-05
# Epoch 40/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 7.9653e-05
# Epoch 41/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 8.7391e-05
# Epoch 42/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 82ms/step - loss: 8.2342e-05
# Epoch 43/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 57ms/step - loss: 7.8249e-05
# Epoch 44/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 7.7592e-05
# Epoch 45/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 7.4899e-05
# Epoch 46/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 54ms/step - loss: 8.1642e-05
# Epoch 47/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 7.9869e-05
# Epoch 48/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - loss: 7.9142e-05
# Epoch 49/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 8.1756e-05
# Epoch 50/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 54ms/step - loss: 7.9568e-05
# Epoch 51/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 8.6118e-05
# Epoch 52/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 8.0962e-05
# Epoch 53/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 8.0051e-05
# Epoch 54/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 8.1050e-05
# Epoch 55/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 57ms/step - loss: 7.7634e-05
# Epoch 56/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 8.9871e-05
# Epoch 57/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 8.5128e-05
# Epoch 58/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 7.9268e-05
# Epoch 59/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 47ms/step - loss: 7.5520e-05
# Epoch 60/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 7.6471e-05
# Epoch 61/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 44ms/step - loss: 7.7790e-05
# Epoch 62/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 8.0224e-05
# Epoch 63/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 8.0781e-05
# Epoch 64/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 7.5956e-05
# Epoch 65/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 7.8475e-05
# Epoch 66/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 7.6693e-05
# Epoch 67/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 7.5835e-05
# Epoch 68/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 7.8237e-05
# Epoch 69/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 42ms/step - loss: 8.1793e-05
# Epoch 70/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 8.7581e-05
# Epoch 71/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 7.9798e-05
# Epoch 72/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 5s 42ms/step - loss: 7.8081e-05
# Epoch 73/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 8.2191e-05
# Epoch 74/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 7.7482e-05
# Epoch 75/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 43ms/step - loss: 7.6565e-05
# Epoch 76/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 8.3667e-05
# Epoch 77/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 7.7240e-05
# Epoch 78/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 7.5430e-05
# Epoch 79/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 43ms/step - loss: 7.6600e-05
# Epoch 80/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 8.0104e-05
# Epoch 81/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 7.4560e-05
# Epoch 82/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 7.8824e-05
# Epoch 83/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 8.2724e-05
# Epoch 84/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step - loss: 7.8491e-05
# Epoch 85/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 50ms/step - loss: 8.4722e-05
# Epoch 86/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 47ms/step - loss: 7.9693e-05
# Epoch 87/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 7.7623e-05
# Epoch 88/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 8.0889e-05
# Epoch 89/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 8.0801e-05
# Epoch 90/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 7.4269e-05
# Epoch 91/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 65ms/step - loss: 8.0928e-05
# Epoch 92/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - loss: 8.3901e-05
# Epoch 93/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 68ms/step - loss: 7.8439e-05
# Epoch 94/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - loss: 8.0370e-05
# Epoch 95/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 8.4533e-05
# Epoch 96/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 8.2942e-05
# Epoch 97/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 7.7155e-05
# Epoch 98/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 7.9538e-05
# Epoch 99/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 7.7181e-05
# Epoch 100/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 7.7129e-05
# Epoch 101/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 60ms/step - loss: 7.7075e-05
# Epoch 102/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 67ms/step - loss: 8.1724e-05
# Epoch 103/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 57ms/step - loss: 8.2932e-05
# Epoch 104/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - loss: 7.7033e-05
# Epoch 105/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 7.7609e-05
# Epoch 106/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 7.8405e-05
# Epoch 107/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 8.0488e-05
# Epoch 108/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 71ms/step - loss: 7.7287e-05
# Epoch 109/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 61ms/step - loss: 7.9418e-05
# Epoch 110/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 65ms/step - loss: 8.0244e-05
# Epoch 111/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 8.3798e-05
# Epoch 112/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 59ms/step - loss: 7.6467e-05
# Epoch 113/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 67ms/step - loss: 7.7190e-05
# Epoch 114/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 75ms/step - loss: 7.7280e-05
# Epoch 115/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 63ms/step - loss: 7.8560e-05
# Epoch 116/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 45ms/step - loss: 7.8016e-05
# Epoch 117/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - loss: 8.1782e-05
# Epoch 118/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 13s 97ms/step - loss: 8.1422e-05
# Epoch 119/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 68ms/step - loss: 7.9212e-05
# Epoch 120/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - loss: 8.1531e-05
# Epoch 121/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 62ms/step - loss: 9.1000e-05
# Epoch 122/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 57ms/step - loss: 7.5546e-05
# Epoch 123/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 7.6017e-05
# Epoch 124/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 7.9775e-05
# Epoch 125/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 7.9352e-05
# Epoch 126/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 70ms/step - loss: 7.8594e-05
# Epoch 127/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 65ms/step - loss: 7.5649e-05
# Epoch 128/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 74ms/step - loss: 7.6930e-05
# Epoch 129/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 84ms/step - loss: 8.0978e-05
# Epoch 130/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 8.2626e-05
# Epoch 131/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 62ms/step - loss: 8.3214e-05
# Epoch 132/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 64ms/step - loss: 7.9377e-05
# Epoch 133/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 7.7883e-05
# Epoch 134/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 62ms/step - loss: 7.5653e-05
# Epoch 135/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 116ms/step - loss: 7.9642e-05
# Epoch 136/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 113ms/step - loss: 7.7998e-05
# Epoch 137/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: 7.9393e-05
# Epoch 138/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 20s 80ms/step - loss: 7.5037e-05
# Epoch 139/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 110ms/step - loss: 7.6822e-05
# Epoch 140/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 8.7128e-05
# Epoch 141/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 72ms/step - loss: 7.7514e-05
# Epoch 142/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 7.4838e-05
# Epoch 143/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - loss: 7.9035e-05
# Epoch 144/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 8.4163e-05
# Epoch 145/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 75ms/step - loss: 7.7054e-05
# Epoch 146/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 86ms/step - loss: 7.8053e-05
# Epoch 147/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - loss: 7.5657e-05
# Epoch 148/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 7.5217e-05
# Epoch 149/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 50ms/step - loss: 8.3329e-05
# Epoch 150/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 13s 69ms/step - loss: 7.8351e-05
# Epoch 151/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 77ms/step - loss: 8.3224e-05
# Epoch 152/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 7.6067e-05
# Epoch 153/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 79ms/step - loss: 8.1867e-05
# Epoch 154/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - loss: 8.3159e-05
# Epoch 155/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 24s 114ms/step - loss: 8.5036e-05
# Epoch 156/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 15s 113ms/step - loss: 7.6100e-05
# Epoch 157/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - loss: 8.1628e-05
# Epoch 158/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 83ms/step - loss: 7.8921e-05
# Epoch 159/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 56ms/step - loss: 7.5195e-05
# Epoch 160/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 72ms/step - loss: 7.5270e-05
# Epoch 161/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 13s 99ms/step - loss: 8.3565e-05
# Epoch 162/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 8.0167e-05
# Epoch 163/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 71ms/step - loss: 7.8928e-05
# Epoch 164/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 8.3785e-05
# Epoch 165/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 7.5451e-05
# Epoch 166/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 46ms/step - loss: 8.4005e-05
# Epoch 167/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 51ms/step - loss: 8.1202e-05
# Epoch 168/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 7.7014e-05
# Epoch 169/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 8.1410e-05
# Epoch 170/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 7.5885e-05
# Epoch 171/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 12s 89ms/step - loss: 7.4362e-05
# Epoch 172/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 17s 61ms/step - loss: 7.7065e-05
# Epoch 173/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 9s 68ms/step - loss: 7.6419e-05
# Epoch 174/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 77ms/step - loss: 7.7093e-05
# Epoch 175/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 44ms/step - loss: 7.5475e-05
# Epoch 176/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 6s 49ms/step - loss: 7.4641e-05
# Epoch 177/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 7.7896e-05
# Epoch 178/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 7.6060e-05
# Epoch 179/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 7.8544e-05
# Epoch 180/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 7.9131e-05
# Epoch 181/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 19s 73ms/step - loss: 8.2451e-05
# Epoch 182/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 82ms/step - loss: 8.8390e-05
# Epoch 183/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 21s 88ms/step - loss: 7.2992e-05
# Epoch 184/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 81ms/step - loss: 8.2413e-05
# Epoch 185/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 76ms/step - loss: 7.6278e-05
# Epoch 186/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - loss: 7.9730e-05
# Epoch 187/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 78ms/step - loss: 7.6919e-05
# Epoch 188/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 84ms/step - loss: 7.8422e-05
# Epoch 189/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 86ms/step - loss: 8.8082e-05
# Epoch 190/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 22s 94ms/step - loss: 7.8365e-05
# Epoch 191/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 88ms/step - loss: 7.7771e-05
# Epoch 192/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 14s 106ms/step - loss: 7.5949e-05
# Epoch 193/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 13s 48ms/step - loss: 7.4838e-05
# Epoch 194/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 10s 80ms/step - loss: 7.9422e-05
# Epoch 195/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - loss: 8.0214e-05
# Epoch 196/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 11s 81ms/step - loss: 7.9744e-05
# Epoch 197/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 58ms/step - loss: 7.9907e-05
# Epoch 199/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 8s 61ms/step - loss: 7.9424e-05
# Epoch 200/200
# 129/129 ━━━━━━━━━━━━━━━━━━━━ 7s 52ms/step - loss: 7.5019e-05

# %%
# Ensure look_back variable exists (your code used 70)
if 'look_back' not in globals():
    look_back = 70

# Create the test dataset (same windowing approach used in training)
test_data = scaled_data[training_data_len - look_back:, :]   # start look_back steps before test split
x_test = []
y_test = []

for i in range(look_back, len(test_data)):
    x_test.append(test_data[i - look_back:i, 0])
    y_test.append(test_data[i, 0])

# Convert to numpy arrays and reshape for LSTM
x_test = np.array(x_test)            # shape (num_samples, look_back)
y_test = np.array(y_test)            # shape (num_samples,)

x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))  # (samples, timesteps, features)

# Predict
predictions_scaled = model.predict(x_test, verbose=0)   # model output in scaled space
# If the model returns shape (n,1) this is fine; otherwise adjust accordingly.
# Inverse-transform predictions
predictions = scaler.inverse_transform(predictions_scaled).ravel()

# Inverse-transform y_test to original scale
y_test_true = scaler.inverse_transform(y_test.reshape(-1,1)).ravel()

# Compute metrics
mape = mean_absolute_percentage_error(y_test_true, predictions) * 100
rmse = np.sqrt(mean_squared_error(y_test_true, predictions))

print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"Root Mean Squared Error (RMSE): {rmse:.4f}")

# Build `valid` / `result_df` aligned with dates
# The dates that correspond to y_test/predictions start at:
# index of df corresponding to training_data_len (since y_test corresponds to df rows training_data_len: )
if 'Date' in df.columns:
    # make sure df has a contiguous Date column aligned with your scaled_data
    dates = pd.to_datetime(df['Date']).reset_index(drop=True)
else:
    dates = pd.to_datetime(df.index).to_series().reset_index(drop=True)

# The test predictions correspond to rows from training_data_len to end of df
start_idx = training_data_len
dates_test = dates[start_idx: start_idx + len(predictions)].reset_index(drop=True)

# True close prices for the same dates (from original df)
actuals = df['Close']['SBIN.NS'].iloc[start_idx : start_idx + len(predictions)].reset_index(drop=True)


# Create a tidy result dataframe
result_df = pd.DataFrame({
    "Date": dates_test,
    "Actual_Close": actuals,
    "Predicted_Close": predictions
})

# Optionally save result_df (change path to your Desktop if you want)
# result_df.to_csv(r"C:\Users\Aditi\Desktop\predicted_vs_actual.csv", index=False)

# Also keep the variables for later cells
valid = result_df.copy()
# Out:
# Mean Absolute Percentage Error (MAPE): 2.20%
# Root Mean Squared Error (RMSE): 21.1524

# %%
# 5. Plot the results
train = df[:training_data_len]
valid = df[training_data_len:]
valid['Predictions'] = predictions

plt.figure(figsize=(16, 8))
plt.title('Fedral Bank Stock Price Prediction')
plt.plot(train['Close'], label='Training Data')
plt.plot(valid['Close'], label='Actual Prices')
plt.plot(valid['Predictions'], label='Predicted Prices')
plt.xlabel('Date')
plt.ylabel('Closing Price INR')
plt.legend(['Training Data', 'Actual Prices', 'Predicted Prices'], loc='lower right')
plt.show()
# Out:
# C:\Users\Aditi\AppData\Local\Temp\ipykernel_14228\3147065517.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   valid['Predictions'] = predictions

# %%
pwd
# Out:
# 'C:\\Users\\Aditi\\Downloads'

# %%
valid
# Out:
#           Date  Actual_Close  Predicted_Close
# 0   2023-08-01    802.084595       796.367798
# 1   2023-08-02    791.589539       800.177551
# 2   2023-08-03    785.871643       787.364380
# 3   2023-08-04    797.235168       784.203369
# 4   2023-08-07    796.776794       797.570190
# ..         ...           ...              ...
# 524 2025-09-15    967.049988       955.368164
# 525 2025-09-16    966.849976       955.529541
# 526 2025-09-17    966.500000       955.239868
# 527 2025-09-18    976.900024       954.907837
# 528 2025-09-19    966.900024       967.234436
#
# [529 rows x 3 columns]

# %%
if 'Date' not in valid.columns:
    valid = valid.reset_index()

# Select only the Date, Close, and Predictions columns
result_df = valid[[ 'Date', 'Actual_Close', 'Predicted_Close']]

result_df
# Out:
#           Date  Actual_Close  Predicted_Close
# 0   2023-08-01    802.084595       796.367798
# 1   2023-08-02    791.589539       800.177551
# 2   2023-08-03    785.871643       787.364380
# 3   2023-08-04    797.235168       784.203369
# 4   2023-08-07    796.776794       797.570190
# ..         ...           ...              ...
# 524 2025-09-15    967.049988       955.368164
# 525 2025-09-16    966.849976       955.529541
# 526 2025-09-17    966.500000       955.239868
# 527 2025-09-18    976.900024       954.907837
# 528 2025-09-19    966.900024       967.234436
#
# [529 rows x 3 columns]

# %%
# use your training window length (you used 70 earlier)
look_back = 70

def forecast_recursive(days):
    window = scaled_data[-look_back:].reshape(1, look_back, 1).copy()
    preds = []
    for _ in range(days):
        p_scaled = model.predict(window, verbose=0).ravel()[0]
        preds.append(p_scaled)
        window = np.append(window[:,1:,:], [[[p_scaled]]], axis=1)
    preds = np.array(preds).reshape(-1,1)
    return scaler.inverse_transform(preds).ravel()

# Forecast horizons
next_day_val  = float(forecast_recursive(1)[0])
next_week_vals = forecast_recursive(5)   # 5 trading days
next_month_vals = forecast_recursive(22) # ~22 trading days

# Build date ranges starting the day after last date in your df
if 'Date' in df.columns:
    last_date = pd.to_datetime(df['Date'].iloc[-1])
else:
    last_date = pd.to_datetime(df.index[-1])

dates_1 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=1, freq='B')
dates_5 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=5, freq='B')
dates_22 = pd.date_range(start=last_date + pd.Timedelta(days=1), periods=22, freq='B')

# Compose tidy dataframe of forecasts
df_day = pd.DataFrame({"Horizon":"Next Day", "Date":dates_1, "Predicted_Close":[next_day_val]})
df_week = pd.DataFrame({"Horizon":"Next Week", "Date":dates_5, "Predicted_Close":next_week_vals})
df_month = pd.DataFrame({"Horizon":"Next Month", "Date":dates_22, "Predicted_Close":next_month_vals})

future_forecasts = pd.concat([df_day, df_week, df_month], ignore_index=True)

# Print short summary and show table
print("Next Day:", round(next_day_val,4))
print("Next Week (5):", [round(v,4) for v in next_week_vals])
print("Next Month (22) first 5:", [round(v,4) for v in next_month_vals[:5]])
# Out:
# Next Day: 951.0685
# Next Week (5): [951.0685, 938.5567, 928.3316, 919.2862, 911.156]
# Next Month (22) first 5: [951.0685, 938.5567, 928.3316, 919.2862, 911.156]

# %%
# Save entire forecast DataFrame
future_forecasts.to_csv("C:/Users/Aditi/Downloads/future_forecasts.csv", index=False)

# %%
# --- Fetch today's live price (intraday latest) ---
import yfinance as yf
import pandas as pd

stock_symbol = 'HDFCBANK.NS'

# Get today's 1-minute interval data
latest_data = yf.download(stock_symbol, period="1d", interval="1m")

# Extract the last available price
latest_price = float(latest_data['Close'].iloc[-1])
latest_time = latest_data.index[-1]  # includes both date and time

print(f"Latest Market Price on {latest_time}: {latest_price:.2f} INR")

# Save to CSV for Power BI
latest_price_df = pd.DataFrame({
    "DateTime": [latest_time],
    "Latest_Close": [latest_price]
})
latest_price_df.to_csv("C:/Users/Aditi/Downloads/latest_price.csv", index=False)
# Out:
# C:\Users\Aditi\AppData\Local\Temp\ipykernel_10192\2095073091.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   latest_data = yf.download(stock_symbol, period="1d", interval="1m")
# [*********************100%***********************]  1 of 1 completed
# Latest Market Price on 2025-09-19 09:59:00+00:00: 967.00 INR
# C:\Users\Aditi\AppData\Local\Temp\ipykernel_10192\2095073091.py:11: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   latest_price = float(latest_data['Close'].iloc[-1])
